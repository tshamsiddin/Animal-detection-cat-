# %% [markdown]
# ![picture](https://doc.google.com/uc?id=1-SCmtVCHxEXXpBfRMwvY_gBrDFA6Pb3u)
#
# # Cat Classification with Tensorflow 2.0
#
# # Training Notebook
#
# ## Level: Beginner

# %% [markdown]
# In this short hands-on activity, you will build a simple cat neural network classifier with Tensorlow 2.0
#
# 1. Build a neural network that classifies cat images.
# 2. Train this neural network.
# 3. And, finally, evaluate the accuracy of the model.

# %% [markdown]
# ## Note ##
# The dataset used is provided by this kaggle repository https://www.kaggle.com/tongpython/cat-and-dog

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Import Libraries ##

# %%
#import tensorflow
import tensorflow as tf
#check the version of tensorflow, make sure it version 2.0 and above
print (tf.__version__)
# Out:
# 2.7.0

# %%
#import pillow
from PIL import Image
from random import shuffle, choice
#import numpy arrays libraries
import numpy as np
#import operating system library
import os

#import keras and its libraries
from tensorflow.keras import datasets, layers, models

os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %% [markdown]
# Then, we import some other libraries including:
#
# * __PIL__ is the Python Imaging Library (abbreviated as PIL) (in newer versions known as Pillow) is a free library for the Python programming language that adds support for opening, manipulating, and saving many different image file formats. It is available for Windows, Mac OS X and Linux
#
# * the module __random__ implements pseudo-random number generators for various distributions
#
# * the __numpy__ module is for numpy array manpiulation
#
# * the __os__ module is the Operating System module and allows to have access to folders and files stored in the hard drive, like for example accessing the images of the dataset
#
# * __tensorflow.keras__, this is the module of keras in tensorflow, which will be used to build our neural network model in a very easy manner

# %% [markdown]
# ## One-Hot Encoding ##

# %%
IMAGE_SIZE = 256

def one_hot_encode(class_name):
    if class_name == 'cats': return np.array([1, 0])
    elif class_name == 'notcats' : return np.array([0, 1])

# %% [markdown]
# Now, we set the size of our image to 256 by 256 pixels. Note that our training and test images may have different and various sizes. However, this size means that we will resize all the images to be 256 by 256 pixels.  Remember that the input size of a neural network is fixed, and in our case, it is 256x256=65536 pixels.
#
# The method __one_hot_encode(name)__ take a string as a parameter, and create a label to the image. Note that the label for cat is the numpy array [1,0] and the label for not cat is [0,1]. This technique is a very common technique in machine learning is known as the __one-hot encoding__.
# One hot encoding is a process by which categorical variables are converted into a form that could be provided to ML algorithms to do a better job in prediction. You can read more about one-hot encoding in this link https://towardsdatascience.com/an-overview-of-categorical-input-handling-for-neural-networks-c172ba552dee
#
# Let us test this function

# %%
print('cats->',one_hot_encode('cats'))
# Out:
# cats-> [1 0]

# %%
print('notcats->',one_hot_encode('notcats'))
# Out:
# notcats-> [0 1]

# %% [markdown]
# So, [1 0] array refers to a cat class, and [0 1] refers to a non-cat class

# %% [markdown]
# ## Loading the training data ##

# %%
IMAGE_DIRECTORY = './drive/MyDrive/cat-dog/dataset/training_set'
def load_data(IMAGE_DIRECTORY, number_of_images=100,shuffle_data=True):
    print("Loading images...")
    train_data = []
    folders = next(os.walk(IMAGE_DIRECTORY))[1]

    for folder_name in folders:
        print("Loading {0}".format(folder_name))
        file_names = next(os.walk(os.path.join(IMAGE_DIRECTORY, folder_name)))[2]

        for i in range(number_of_images):
            image_name = choice(file_names)
            image_path = os.path.join(IMAGE_DIRECTORY, folder_name, image_name)
            #print(image_path)
            label = one_hot_encode(folder_name)
            class_name=folder_name
            if "DS_Store" not in image_path:
                img = Image.open(image_path)
                img = img.convert('L')
                img = img.resize((IMAGE_SIZE, IMAGE_SIZE), Image.ANTIALIAS)
                train_data.append([np.array(img), label,class_name])
    
    if (shuffle_data==True):
        shuffle(train_data)
    print('we loaded ',len(train_data),'images in the training dataset')
    return train_data

# %% [markdown]
# The function __load_data__ is responsible for loading the training dataset. First, we set the IMAGE_DIRECTORY valriable to './data/training_set', which refers to the training dataset.
#
# The training data will be loaded into the list __train_data__. Initially, the list of empty.
# Then, the variale directories will get the tree structure of all directories in the specified path.
#
# __os.walk()__ generates the file names in a directory tree by walking the tree either top-down or bottom-up. For each directory in the tree rooted at directory top (including top itself), it yields a 3-tuple (dirpath, dirnames, filenames).
#
# * root : Prints out directories only from what you specified.
# * dirs : Prints out sub-directories from root.
# * files : Prints out all files from root and directories.
#
# Let us try to see the effect of OS.walk()

# %%
PROJECT_PATH='/content/drive/MyDrive/cat-dog/'
IMAGE_DIRECTORY = PROJECT_PATH+'dataset/training_set/' #or data/training_set
print("os.walk(IMAGE_DIRECTORY)", os.walk(IMAGE_DIRECTORY))

#print("os.walk(IMAGE_DIRECTORY)", next(os.walk(IMAGE_DIRECTORY))[0])
#print(next(os.walk(IMAGE_DIRECTORY))[1])
#print(next(os.walk(IMAGE_DIRECTORY))[2])
# Out:
# os.walk(IMAGE_DIRECTORY) <generator object walk at 0x7fca448f8950>

# %%
i=0
for root,sub_directories, files in (os.walk(IMAGE_DIRECTORY)):
    print("Level ",i)
    print("root folder:", root)
    print("sub folders:",sub_directories)
    print("number of files in the root folder:",len(files))
    i=i+1
    print('-----------------------------')
# Out:
# Level  0
# root folder: /content/drive/MyDrive/cat-dog/dataset/training_set/
# sub folders: ['cats', 'notcats']
# number of files in the root folder: 0
# -----------------------------
# Level  1
# root folder: /content/drive/MyDrive/cat-dog/dataset/training_set/cats
# sub folders: []
# number of files in the root folder: 4001
# -----------------------------
# Level  2
# root folder: /content/drive/MyDrive/cat-dog/dataset/training_set/notcats
# sub folders: []
# number of files in the root folder: 1669
# -----------------------------

# %%
folders=next(os.walk(IMAGE_DIRECTORY))
print("paths_tuple in the current directory: \n", folders)
# Out:
# paths_tuple in the current directory:
#  ('/content/drive/MyDrive/cat-dog/dataset/training_set/', ['cats', 'notcats'], [])

# %%
print("THE ROOT FOLDER")
print("os.walk(IMAGE_DIRECTORY)[0]: ", next(os.walk(IMAGE_DIRECTORY))[0])
print("folders[0]             : ", folders[0])
# Out:
# THE ROOT FOLDER
# os.walk(IMAGE_DIRECTORY)[0]:  /content/drive/MyDrive/cat-dog/dataset/training_set/
# folders[0]             :  /content/drive/MyDrive/cat-dog/dataset/training_set/

# %%
print("THE SUBDIRECTORIES FROM THE ROOT")
print("os.walk(IMAGE_DIRECTORY)[1]: ", next(os.walk(IMAGE_DIRECTORY))[1])
print("folders[1]          : ", folders[1])
# Out:
# THE SUBDIRECTORIES FROM THE ROOT
# os.walk(IMAGE_DIRECTORY)[1]:  ['cats', 'notcats']
# folders[1]          :  ['cats', 'notcats']

# %%
print("THE FILES IN THE ROOT FOLDER")
# Out:
# THE FILES IN THE ROOT FOLDER

# %%
IMAGE_DIRECTORY = PROJECT_PATH+'dataset/training_set'
folders = next(os.walk(IMAGE_DIRECTORY))[1]
for folder_name in folders:
    print("Loading {0}".format(folder_name))
# Out:
# Loading cats
# Loading notcats

# %% [markdown]
# Observe that the three contains three main levels. The root level (level 0) contains the root directory which is "./data/training_set". The second level (index = 1) corresponds to the two folders inside the root folder, namely the 'cats' folder and 'notcats' folder. The third level (index=2) corresponds to the hidden folder '.DS_Store'.

# %%
os.listdir(IMAGE_DIRECTORY)
# Out:
# ['cats', 'notcats']

# %%
! ls
# Out:
# drive  sample_data

# %%
! ls ./drive/MyDrive/cat-dog/dataset/training_set
# Out:
# cats  notcats

# %% [markdown]
# This is also another option on how we show the list of directories and files inside a folder.

# %% [markdown]
# The following instruction is responsible for getting the file names in every directory found in the tree.
# <code>
# for folder_name in folders:
#         print("Loading {0}".format(folder_name))
#         file_names = next(os.walk(os.path.join(IMAGE_DIRECTORY, folder_name)))[2]
# </code>
#
# __dirname__ will contain the name of the directory found in the tree
# __file_names__ will get the list of all files found in the directory.
#
# <hr>
#
# ### Note ###
# OS module in Python provides functions for interacting with the operating system. OS comes under Python’s standard utility modules. This module provides a portable way of using operating system dependent functionality. os.path module is sub-module of OS module in Python used for common pathname manipulation.
#
# __os.path.join()__ method in Python join one or more path components intelligently. This method concatenates various path components with exactly one directory separator (‘/’) following each non-empty part except the last path component. If the last path component to be joined is empty then a directory seperator (‘/’) is put at the end.
# If a path component represents an absolute path, then all previous components joined are discarded and joining continues from the absolute path component.
#  (_reference:_ https://www.geeksforgeeks.org/python-os-path-join-method/)
#
#  <hr>

# %% [markdown]
# To understand more the os method, please follow the illustrative code below

# %%
IMAGE_DIRECTORY = PROJECT_PATH+'dataset/training_set'
training_data_directory = next(os.walk(IMAGE_DIRECTORY))[1]
print ('training_data_directory: ', training_data_directory)
# Out:
# training_data_directory:  ['cats', 'notcats']

# %%
cats_directory= training_data_directory[0]
notcats_directory= training_data_directory[1]

print ('cats_directory: ', cats_directory)
print ('notcats_directory: ', notcats_directory)
# Out:
# cats_directory:  cats
# notcats_directory:  notcats

# %%
joit_path= os.path.join(IMAGE_DIRECTORY, cats_directory)
print('joint path: ',joit_path)
images_list = next(os.walk(joit_path))[2]
print ('number of images: ', len(images_list))
print ('image list: ',images_list)
# Out:
# joint path:  /content/drive/MyDrive/cat-dog/dataset/training_set/cats
# number of images:  4001
ize((IMAGE_SIZE, IMAGE_SIZE), Image.ANTIALIAS)
#             train_data.append([np.array(img), label])
# </code>
#
# * __choice(file_names):__ returns a random item from a list, tuple, or string.
# * __Image.open(image_path):__ open an image from the path specified
# * __img.convert('L')__: convert image to monochrome
# * __img.resize:__ resize the image to the specified size
# * __ANTIALIAS__: it is a filter that ensures the best quality
# * __train_data.append([np.array(img), label]):__ add the training images and their label into the list
# * __np.array(img)__: cast the image into a numpy array

# %% [markdown]
# ## Building the Neural Network Model ##

# %% [markdown]
# Now that we have our dataset prepare, we are ready to create neural networks.
#
# We will create two types of networks. One fully connected neural networks, and one convolutional neural network.
#
# If you do not have a background on covolutional neural networks, please refer to my online YouTube lecture https://www.youtube.com/watch?v=vibHourRAEc

# %%
from IPython.display import HTML,IFrame
# Youtube
HTML('<iframe width="560" height="315" src="https://www.youtube.com/embed/vibHourRAEc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>')
# Out:
# <iframe width="560" height="315" src="https://www.youtube.com/embed/vibHourRAEc" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# ## Create a convolutional neural network model

# %%
def create_cnn_model():
    model = tf.keras.models.Sequential()
    model.add(layers.Conv2D(32, kernel_size = (5, 5), activation='relu', 
                   input_shape=(IMAGE_SIZE, IMAGE_SIZE, 1)))
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(64, kernel_size=(3,3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(128, kernel_size=(3,3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.BatchNormalization())
    model.add(layers.Conv2D(256, kernel_size=(3,3), activation='relu'))
    model.add(layers.MaxPooling2D(pool_size=(2,2)))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))
    model.add(layers.Flatten())
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.BatchNormalization())
    model.add(layers.Dropout(0.5))
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(2, activation = 'softmax'))
    
    return model

# %% [markdown]
# ## Create a fully connected neural network

# %%
def create_model():
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Flatten(input_shape=(IMAGE_SIZE, IMAGE_SIZE,1)))
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(32, activation='relu'))
    model.add(layers.Dense(2, activation = 'softmax'))
    
    return model

# %%
IMAGE_DIRECTORY = PROJECT_PATH+'dataset/training_set'
import datetime
t0=datetime.datetime.now()
train_data = load_data(IMAGE_DIRECTORY,number_of_images=200,shuffle_data=True)
t1=datetime.datetime.now()
print("time to load data", (t1-t0))
trainX = np.array([i[0] for i in train_data]).reshape(-1, IMAGE_SIZE, IMAGE_SIZE, 1)
trainY = np.array([i[1] for i in train_data])


print(trainX.shape)
print(trainY.shape)
# Out:
# Loading images...
# Loading cats
# Loading notcats
# we loaded  400 images in the training dataset
# time to load data 0:03:59.612624
# (400, 256, 256, 1)
# (400, 2)

# %%
image_index=1
label = train_data[image_index][1]
class_name=train_data[image_index][2]
print ("label:", label)
print ("class name:", class_name)
image = plt.imshow(train_data[image_index][0])
# Out:
# label: [1 0]
# class name: cats

# %%
image_index=200
label = train_data[image_index][1]
class_name=train_data[image_index][2]
print ("label:", label)
print ("class name:", class_name)
image = plt.imshow(train_data[image_index][0])
# Out:
# label: [0 1]
# class name: notcats

# %%
IMAGE_DIRECTORY = PROJECT_PATH+'dataset/test_set'

t0=datetime.datetime.now()
test_data = load_data(IMAGE_DIRECTORY,number_of_images=100,shuffle_data=True)
t1=datetime.datetime.now()
print("time to load data", (t1-t0))

testX = np.array([i[0] for i in test_data]).reshape(-1, IMAGE_SIZE, IMAGE_SIZE, 1)
testY = np.array([i[1] for i in test_data])


print(testX.shape)
print(testY.shape)
# Out:
# Loading images...
# Loading notcats
# Loading cats
# we loaded  200 images in the training dataset
# time to load data 0:02:28.765773
# (200, 256, 256, 1)
# (200, 2)

# %% [markdown]
# # Training with a convolutional neural network model

# %%
import tensorflow as tf
from tensorflow.keras.optimizers import SGD
print('creating model')
model = create_cnn_model()
opt=tf.keras.optimizers.SGD(learning_rate=1e-4, momentum=0.9)
model.compile(loss='categorical_crossentropy', 
              optimizer=opt, 
              metrics=['accuracy'])
# Out:
# creating model

# %%
BATCH_SIZE=64
EPOCHS=100

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 252, 252, 32)      832
#
#  max_pooling2d (MaxPooling2D  (None, 126, 126, 32)     0
#  )
#
#  batch_normalization (BatchN  (None, 126, 126, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 124, 124, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 62, 62, 64)       0
#  2D)
#
#  batch_normalization_1 (Batc  (None, 62, 62, 64)       256
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 60, 60, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 30, 30, 128)      0
#  2D)
#
#  batch_normalization_2 (Batc  (None, 30, 30, 128)      512
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 28, 28, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 14, 14, 256)      0
#  2D)
#
#  batch_normalization_3 (Batc  (None, 14, 14, 256)      1024
#  hNormalization)
#
#  dropout (Dropout)           (None, 14, 14, 256)       0
#
#  flatten (Flatten)           (None, 50176)             0
#
#  dense (Dense)               (None, 64)                3211328
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 2)                 66
#
# =================================================================
# Total params: 3,604,002
# Trainable params: 3,602,914
# Non-trainable params: 1,088
# _________________________________________________________________

# %%
from tensorflow.keras.utils import plot_model
plot_model(model,show_shapes=True, show_layer_names=True, rankdir='TB', expand_nested=True)

# %%
print('training model')
t0=datetime.datetime.now()
history=model.fit(trainX, trainY, 
          batch_size=BATCH_SIZE, 
          epochs=EPOCHS, 
          verbose=1,
          validation_data=(testX, testY)
         )
t1=datetime.datetime.now()
print("time to load data", (t1-t0))
# Out:
# training model
# Epoch 1/100
# 7/7 [==============================] - 37s 506ms/step - loss: 1.1426 - accuracy: 0.5250 - val_loss: 1.8651 - val_accuracy: 0.5000
# Epoch 2/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.9891 - accuracy: 0.5550 - val_loss: 1.7632 - val_accuracy: 0.5000
# Epoch 3/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.9436 - accuracy: 0.5825 - val_loss: 1.8123 - val_accuracy: 0.5000
# Epoch 4/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.8260 - accuracy: 0.6125 - val_loss: 1.4030 - val_accuracy: 0.5000
# Epoch 5/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.8075 - accuracy: 0.6300 - val_loss: 1.1406 - val_accuracy: 0.5000
# Epoch 6/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.7858 - accuracy: 0.6375 - val_loss: 1.0353 - val_accuracy: 0.5050
# Epoch 7/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.7809 - accuracy: 0.6025 - val_loss: 0.9803 - val_accuracy: 0.5100
# Epoch 8/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.6277 - accuracy: 0.6975 - val_loss: 0.9151 - val_accuracy: 0.5200
# Epoch 9/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.6249 - accuracy: 0.6925 - val_loss: 0.8372 - val_accuracy: 0.5300
# Epoch 10/100
# 7/7 [==============================] - 2s 271ms/step - loss: 0.5800 - accuracy: 0.7150 - val_loss: 0.7755 - val_accuracy: 0.5550
# Epoch 11/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.5133 - accuracy: 0.7525 - val_loss: 0.7300 - val_accuracy: 0.5900
# Epoch 12/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.5418 - accuracy: 0.7425 - val_loss: 0.6785 - val_accuracy: 0.6100
# Epoch 13/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.5602 - accuracy: 0.7425 - val_loss: 0.6397 - val_accuracy: 0.6700
# Epoch 14/100
# 7/7 [==============================] - 2s 280ms/step - loss: 0.5215 - accuracy: 0.7325 - val_loss: 0.6229 - val_accuracy: 0.6900
# Epoch 15/100
# 7/7 [==============================] - 2s 281ms/step - loss: 0.4844 - accuracy: 0.7725 - val_loss: 0.6113 - val_accuracy: 0.7300
# Epoch 16/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.4831 - accuracy: 0.7875 - val_loss: 0.6182 - val_accuracy: 0.7100
# Epoch 17/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.5466 - accuracy: 0.7425 - val_loss: 0.6169 - val_accuracy: 0.7100
# Epoch 18/100
# 7/7 [==============================] - 2s 270ms/step - loss: 0.4708 - accuracy: 0.7650 - val_loss: 0.6235 - val_accuracy: 0.7000
# Epoch 19/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.4303 - accuracy: 0.8000 - val_loss: 0.6108 - val_accuracy: 0.7150
# Epoch 20/100
# 7/7 [==============================] - 2s 280ms/step - loss: 0.4339 - accuracy: 0.7875 - val_loss: 0.5979 - val_accuracy: 0.7300
# Epoch 21/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.3806 - accuracy: 0.8425 - val_loss: 0.5768 - val_accuracy: 0.7400
# Epoch 22/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.4188 - accuracy: 0.7925 - val_loss: 0.5861 - val_accuracy: 0.7250
# Epoch 23/100
# 7/7 [==============================] - 2s 272ms/step - loss: 0.3862 - accuracy: 0.8100 - val_loss: 0.5917 - val_accuracy: 0.7200
# Epoch 24/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0
100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.2152 - accuracy: 0.9175 - val_loss: 0.6480 - val_accuracy: 0.7300
# Epoch 53/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.2231 - accuracy: 0.9225 - val_loss: 0.6381 - val_accuracy: 0.7400
# Epoch 54/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.2271 - accuracy: 0.9175 - val_loss: 0.6238 - val_accuracy: 0.7700
# Epoch 55/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1963 - accuracy: 0.9175 - val_loss: 0.6361 - val_accuracy: 0.7550
# Epoch 56/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1967 - accuracy: 0.9450 - val_loss: 0.6375 - val_accuracy: 0.7450
# Epoch 57/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.1849 - accuracy: 0.9375 - val_loss: 0.6417 - val_accuracy: 0.7350
# Epoch 58/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.2218 - accuracy: 0.9150 - val_loss: 0.6408 - val_accuracy: 0.7400
# Epoch 59/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1798 - accuracy: 0.9375 - val_loss: 0.6438 - val_accuracy: 0.7300
# Epoch 60/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.2429 - accuracy: 0.9000 - val_loss: 0.6659 - val_accuracy: 0.7200
# Epoch 61/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1800 - accuracy: 0.9425 - val_loss: 0.6269 - val_accuracy: 0.7400
# Epoch 62/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.1865 - accuracy: 0.9400 - val_loss: 0.6252 - val_accuracy: 0.7600
# Epoch 63/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.2025 - accuracy: 0.9275 - val_loss: 0.6160 - val_accuracy: 0.7700
# Epoch 64/100
# 7/7 [==============================] - 2s 281ms/step - loss: 0.1941 - accuracy: 0.9275 - val_loss: 0.6403 - val_accuracy: 0.7450
# Epoch 65/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.2001 - accuracy: 0.9200 - val_loss: 0.6727 - val_accuracy: 0.7450
# Epoch 66/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.1640 - accuracy: 0.9525 - val_loss: 0.6507 - val_accuracy: 0.7700
# Epoch 67/100
# 7/7 [==============================] - 2s 282ms/step - loss: 0.1811 - accuracy: 0.9325 - val_loss: 0.6600 - val_accuracy: 0.7500
# Epoch 68/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1772 - accuracy: 0.9300 - val_loss: 0.6722 - val_accuracy: 0.7350
# Epoch 69/100
# 7/7 [==============================] - 2s 280ms/step - loss: 0.1702 - accuracy: 0.9475 - val_loss: 0.6781 - val_accuracy: 0.7450
# Epoch 70/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.1905 - accuracy: 0.9375 - val_loss: 0.6951 - val_accuracy: 0.7450
# Epoch 71/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1619 - accuracy: 0.9500 - val_loss: 0.6863 - val_accuracy: 0.7300
# Epoch 72/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1477 - accuracy: 0.9600 - val_loss: 0.6643 - val_accuracy: 0.7350
# Epoch 73/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1679 - accuracy: 0.9350 - val_loss: 0.6466 - val_accuracy: 0.7400
# Epoch 74/100
# 7/7 [==============================] - 2s 281ms/step - loss: 0.1638 - accuracy: 0.9425 - val_loss: 0.6613 - val_accuracy: 0.7550
# Epoch 75/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1395 - accuracy: 0.9600 - val_loss: 0.6777 - val_accuracy: 0.7600
# Epoch 76/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.1369 - accuracy: 0.9575 - val_loss: 0.6837 - val_accuracy: 0.7600
# Epoch 77/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.1526 - accuracy: 0.9425 - val_loss: 0.6807 - val_accuracy: 0.7650
# Epoch 78/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.1576 - accuracy: 0.9450 - val_loss: 0.6984 - val_accuracy: 0.7350
# Epoch 79/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1517 - accuracy: 0.9400 - val_loss: 0.6908 - val_accuracy: 0.7550
# Epoch 80/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1273 - accuracy: 0.9650 - val_loss: 0.6876 - val_accuracy: 0.7550
# Epoch 81/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.1375 - accuracy: 0.9575 - val_loss: 0.6954 - val_accuracy: 0.7450
# Epoch 82/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.1413 - accuracy: 0.9650 - val_loss: 0.7123 - val_accuracy: 0.7550
# Epoch 83/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1092 - accuracy: 0.9725 - val_loss: 0.6998 - val_accuracy: 0.7450
# Epoch 84/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1368 - accuracy: 0.9575 - val_loss: 0.7226 - val_accuracy: 0.7450
# Epoch 85/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.1435 - accuracy: 0.9500 - val_loss: 0.7187 - val_accuracy: 0.7500
# Epoch 86/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.1546 - accuracy: 0.9425 - val_loss: 0.7079 - val_accuracy: 0.7550
# Epoch 87/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.1499 - accuracy: 0.9400 - val_loss: 0.6942 - val_accuracy: 0.7450
# Epoch 88/100
# 7/7 [==============================] - 2s 282ms/step - loss: 0.1316 - accuracy: 0.9625 - val_loss: 0.7041 - val_accuracy: 0.7400
# Epoch 89/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.1344 - accuracy: 0.9625 - val_loss: 0.7366 - val_accuracy: 0.7300
# Epoch 90/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1337 - accuracy: 0.9625 - val_loss: 0.7526 - val_accuracy: 0.7200
# Epoch 91/100
# 7/7 [==============================] - 2s 273ms/step - loss: 0.1154 - accuracy: 0.9625 - val_loss: 0.7351 - val_accuracy: 0.7500
# Epoch 92/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.1474 - accuracy: 0.9475 - val_loss: 0.6874 - val_accuracy: 0.7600
# Epoch 93/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.1194 - accuracy: 0.9625 - val_loss: 0.6590 - val_accuracy: 0.7550
# Epoch 94/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1055 - accuracy: 0.9800 - val_loss: 0.6593 - val_accuracy: 0.7600
# Epoch 95/100
# 7/7 [==============================] - 2s 277ms/step - loss: 0.1229 - accuracy: 0.9650 - val_loss: 0.6498 - val_accuracy: 0.7650
# Epoch 96/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.1278 - accuracy: 0.9600 - val_loss: 0.6507 - val_accuracy: 0.7700
# Epoch 97/100
# 7/7 [==============================] - 2s 276ms/step - loss: 0.1271 - accuracy: 0.9675 - val_loss: 0.7113 - val_accuracy: 0.7550
# Epoch 98/100
# 7/7 [==============================] - 2s 275ms/step - loss: 0.1087 - accuracy: 0.9725 - val_loss: 0.7160 - val_accuracy: 0.7500
# Epoch 99/100
# 7/7 [==============================] - 2s 281ms/step - loss: 0.1045 - accuracy: 0.9725 - val_loss: 0.6814 - val_accuracy: 0.7700
# Epoch 100/100
# 7/7 [==============================] - 2s 274ms/step - loss: 0.1071 - accuracy: 0.9675 - val_loss: 0.6307 - val_accuracy: 0.7850
# time to load data 0:04:23.363034

# %%
model.save(PROJECT_PATH+"model_cnn.h5")
PROJECT_PATH
# Out:
# '/content/drive/MyDrive/cat-dog/'

# %%
print(history.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
def plot_history(history):

    # summarize history for accuracy
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('model accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()
    # summarize history for loss
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('model loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['train', 'test'], loc='upper left')
    plt.show()

# %%
plot_history(history)

# %% [markdown]
# # Training with a fully-connected neural network model

# %%
print('creating model')
model_nn = create_model()
model_nn.compile(loss='categorical_crossentropy', 
                 optimizer='adam', 
                 metrics=['accuracy'])

#
# Out:
# creating model

# %%
print('training model')
t1=datetime.datetime.now()
history_nn=model_nn.fit(trainX, trainY, 
             batch_size=50, 
             epochs=100, 
             verbose=1,
             validation_data=(testX, testY))
t1=datetime.datetime.now()
print("time to load data", (t1-t0))
# Out:
# training model
# Epoch 1/100
# 8/8 [==============================] - 1s 40ms/step - loss: 1318.9749 - accuracy: 0.4700 - val_loss: 218.3467 - val_accuracy: 0.5200
# Epoch 2/100
# 8/8 [==============================] - 0s 17ms/step - loss: 238.1823 - accuracy: 0.5250 - val_loss: 299.9377 - val_accuracy: 0.5050
# Epoch 3/100
# 8/8 [==============================] - 0s 22ms/step - loss: 502.6226 - accuracy: 0.4875 - val_loss: 367.7908 - val_accuracy: 0.5100
# Epoch 4/100
# 8/8 [==============================] - 0s 23ms/step - loss: 227.8937 - accuracy: 0.6075 - val_loss: 302.0019 - val_accuracy: 0.5200
# Epoch 5/100
# 8/8 [==============================] - 0s 17ms/step - loss: 217.0896 - accuracy: 0.5875 - val_loss: 98.6207 - val_accuracy: 0.6450
# Epoch 6/100
# 8/8 [==============================] - 0s 19ms/step - loss: 292.4583 - accuracy: 0.5600 - val_loss: 282.5280 - val_accuracy: 0.5300
# Epoch 7/100
# 8/8 [==============================] - 0s 16ms/step - loss: 334.1439 - accuracy: 0.5250 - val_loss: 320.6699 - val_accuracy: 0.5050
# Epoch 8/100
# 8/8 [==============================] - 0s 23ms/step - loss: 290.4606 - accuracy: 0.5200 - val_loss: 370.4788 - val_accuracy: 0.5100
# Epoch 9/100
# 8/8 [==============================] - 0s 16ms/step - loss: 215.1197 - accuracy: 0.5925 - val_loss: 98.2182 - val_accuracy: 0.6700
# Epoch 10/100
# 8/8 [==============================] - 0s 17ms/step - loss: 76.3703 - accuracy: 0.6975 - val_loss: 119.6636 - val_accuracy: 0.5900
# Epoch 11/100
# 8/8 [==============================] - 0s 17ms/step - loss: 48.4572 - accuracy: 0.7200 - val_loss: 67.0261 - val_accuracy: 0.5900
# Epoch 12/100
# 8/8 [==============================] - 0s 18ms/step - loss: 67.3558 - accuracy: 0.6500 - val_loss: 222.7311 - val_accuracy: 0.5000
# Epoch 13/100
# 8/8 [==============================] - 0s 17ms/step - loss: 116.7666 - accuracy: 0.5800 - val_loss: 120.4275 - val_accuracy: 0.5450
# Epoch 14/100
# 8/8 [==============================] - 0s 17ms/step - loss: 52.4977 - accuracy: 0.7150 - val_loss: 74.7106 - val_accuracy: 0.6150
# Epoch 15/100
# 8/8 [==============================] - 0s 17ms/step - loss: 30.7868 - accuracy: 0.7475 - val_loss: 70.3622 - val_accuracy: 0.5450
# Epoch 16/100
# 8/8 [==============================] - 0s 17ms/step - loss: 20.2684 - accuracy: 0.7800 - val_loss: 66.7268 - val_accuracy: 0.5700
# Epoch 17/100
# 8/8 [==============================] - 0s 17ms/step - loss: 30.5979 - accuracy: 0.7225 - val_loss: 56.3173 - val_accuracy: 0.5850
# Epoch 18/100
# 8/8 [==============================] - 0s 23ms/step - loss: 20.3098 - accuracy: 0.7825 - val_loss: 44.9688 - val_accuracy: 0.5800
# Epoch 38/100
# 8/8 [==============================] - 0s 18ms/step - loss: 83.7103 - accuracy: 0.6775 - val_loss: 206.7580 - val_accuracy: 0.5300
# Epoch 39/100
# 8/8 [==============================] - 0s 18ms/step - loss: 41.3648 - accuracy: 0.7725 - val_loss: 95.2766 - val_accuracy: 0.5700
# Epoch 40/100
# 8/8 [==============================] - 0s 17ms/step - loss: 14.3189 - accuracy: 0.8575 - val_loss: 57.0341 - val_accuracy: 0.5850
# Epoch 41/100
# 8/8 [==============================] - 0s 17ms/step - loss: 7.9036 - accuracy: 0.8900 - val_loss: 57.5027 - val_accuracy: 0.5750
# Epoch 42/100
# 8/8 [==============================] - 0s 17ms/step - loss: 14.1068 - accuracy: 0.8400 - val_loss: 68.5125 - val_accuracy: 0.5650
# Epoch 43/100
# 8/8 [==============================] - 0s 22ms/step - loss: 17.2468 - accuracy: 0.8425 - val_loss: 113.2162 - val_accuracy: 0.5800
# Epoch 44/100
# 8/8 [==============================] - 0s 17ms/step - loss: 20.3478 - accuracy: 0.8350 - val_loss: 63.1963 - val_accuracy: 0.5900
# Epoch 45/100
# 8/8 [==============================] - 0s 18ms/step - loss: 3.3738 - accuracy: 0.9425 - val_loss: 59.7270 - val_accuracy: 0.5950
# Epoch 46/100
# 8/8 [==============================] - 0s 16ms/step - loss: 3.9338 - accuracy: 0.9350 - val_loss: 50.9283 - val_accuracy: 0.5850
# Epoch 47/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.6737 - accuracy: 0.9475 - val_loss: 75.2802 - val_accuracy: 0.5850
# Epoch 48/100
# 8/8 [==============================] - 0s 17ms/step - loss: 9.1945 - accuracy: 0.8800 - val_loss: 126.7765 - val_accuracy: 0.5550
# Epoch 49/100
# 8/8 [==============================] - 0s 17ms/step - loss: 25.3727 - accuracy: 0.7875 - val_loss: 74.8412 - val_accuracy: 0.5900
# Epoch 50/100
# 8/8 [==============================] - 0s 17ms/step - loss: 18.7475 - accuracy: 0.8550 - val_loss: 103.1702 - val_accuracy: 0.6050
# Epoch 51/100
# 8/8 [==============================] - 0s 17ms/step - loss: 7.0532 - accuracy: 0.9175 - val_loss: 60.6538 - val_accuracy: 0.5550
# Epoch 52/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.9596 - accuracy: 0.9350 - val_loss: 53.6216 - val_accuracy: 0.6150
# Epoch 53/100
# 8/8 [==============================] - 0s 17ms/step - loss: 4.7656 - accuracy: 0.9100 - val_loss: 53.3851 - val_accuracy: 0.5850
# Epoch 54/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.1170 - accuracy: 0.9625 - val_loss: 57.2189 - val_accuracy: 0.5850
# Epoch 55/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.2392 - accuracy: 0.9750 - val_loss: 48.0595 - val_accuracy: 0.5800
# Epoch 56/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3053 - accuracy: 0.9875 - val_loss: 61.9781 - val_accuracy: 0.5900
# Epoch 57/100
# 8/8 [==============================] - 0s 18ms/step - loss: 1.5145 - accuracy: 0.9550 - val_loss: 59.5062 - val_accuracy: 0.5700
# Epoch 58/100
# 8/8 [==============================] - 0s 17ms/step - loss: 5.0143 - accuracy: 0.8825 - val_loss: 80.6611 - val_accuracy: 0.5300
# Epoch 59/100
# 8/8 [==============================] - 0s 23ms/step - loss: 13.8184 - accuracy: 0.8225 - val_loss: 66.9012 - val_accuracy: 0.5650
# Epoch 60/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.9287 - accuracy: 0.9350 - val_loss: 60.6063 - val_accuracy: 0.5850
# Epoch 61/100
# 8/8 [==============================] - 0s 17ms/step - loss: 7.1576 - accuracy: 0.8675 - val_loss: 71.2894 - val_accuracy: 0.5900
# Epoch 62/100
# 8/8 [==============================] - 0s 18ms/step - loss: 1.2459 - accuracy: 0.9575 - val_loss: 64.0371 - val_accuracy: 0.5750
# Epoch 63/100
# 8/8 [==============================] - 0s 20ms/step - loss: 0.9833 - accuracy: 0.9700 - val_loss: 52.2624 - val_accuracy: 0.5800
# Epoch 64/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.1596 - accuracy: 0.9925 - val_loss: 51.1373 - val_accuracy: 0.5850
# Epoch 65/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.0391 - accuracy: 0.9975 - val_loss: 53.2184 - val_accuracy: 0.5750
# Epoch 66/100
# 8/8 [==============================] - 0s 23ms/step - loss: 0.1395 - accuracy: 0.9950 - val_loss: 62.0648 - val_accuracy: 0.5850
# Epoch 67/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.3104 - accuracy: 0.9800 - val_loss: 52.9903 - val_accuracy: 0.5850
# Epoch 68/100
# 8/8 [==============================] - 0s 18ms/step - loss: 2.6211e-04 - accuracy: 1.0000 - val_loss: 51.1323 - val_accuracy: 0.5500
# Epoch 69/100
# 8/8 [==============================] - 0s 17ms/step - loss: 9.2658e-04 - accuracy: 1.0000 - val_loss: 52.6828 - val_accuracy: 0.5550
# Epoch 70/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.3143 - accuracy: 0.9875 - val_loss: 68.4490 - val_accuracy: 0.5700
# Epoch 71/100
# 8/8 [==============================] - 0s 16ms/step - loss: 0.4028 - accuracy: 0.9825 - val_loss: 52.1050 - val_accuracy: 0.5800
# Epoch 72/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4604 - accuracy: 0.9800 - val_loss: 53.8406 - val_accuracy: 0.5750
# Epoch 73/100
# 8/8 [==============================] - 0s 17ms/step - loss: 4.6859 - accuracy: 0.9050 - val_loss: 75.5499 - val_accuracy: 0.5700
# Epoch 74/100
# 8/8 [==============================] - 0s 17ms/step - loss: 1.2413 - accuracy: 0.9650 - val_loss: 54.8983 - val_accuracy: 0.5850
# Epoch 75/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.7738 - accuracy: 0.9800 - val_loss: 62.9435 - val_accuracy: 0.5600
# Epoch 76/100
# 8/8 [==============================] - 0s 17ms/step - loss: 26.5074 - accuracy: 0.8075 - val_loss: 124.9995 - val_accuracy: 0.5050
# Epoch 77/100
# 8/8 [==============================] - 0s 17ms/step - loss: 165.2681 - accuracy: 0.5625 - val_loss: 403.5574 - val_accuracy: 0.5000
# Epoch 78/100
# 8/8 [==============================] - 0s 17ms/step - loss: 182.5658 - accuracy: 0.6275 - val_loss: 181.5929 - val_accuracy: 0.5850
# Epoch 79/100
# 8/8 [==============================] - 0s 20ms/step - loss: 89.6452 - accuracy: 0.7050 - val_loss: 97.7658 - val_accuracy: 0.6550
# Epoch 80/100
# 8/8 [==============================] - 0s 17ms/step - loss: 87.9372 - accuracy: 0.6925 - val_loss: 71.1512 - val_accuracy: 0.6200
# Epoch 81/100
# 8/8 [==============================] - 0s 17ms/step - loss: 26.7106 - accuracy: 0.7950 - val_loss: 60.6910 - val_accuracy: 0.5650
# Epoch 82/100
# 8/8 [==============================] - 0s 18ms/step - loss: 16.1729 - accuracy: 0.8300 - val_loss: 61.2246 - val_accuracy: 0.5850
# Epoch 83/100
# 8/8 [==============================] - 0s 23ms/step - loss: 33.9124 - accuracy: 0.7450 - val_loss: 139.0522 - val_accuracy: 0.5950
# Epoch 84/100
# 8/8 [==============================] - 0s 17ms/step - loss: 37.3568 - accuracy: 0.7750 - val_loss: 83.4972 - val_accuracy: 0.5900
# Epoch 85/100
# 8/8 [==============================] - 0s 18ms/step - loss: 38.2537 - accuracy: 0.7750 - val_loss: 75.8917 - val_accuracy: 0.6250
# Epoch 86/100
# 8/8 [==============================] - 0s 17ms/step - loss: 40.1307 - accuracy: 0.7400 - val_loss: 68.3693 - val_accuracy: 0.6050
# Epoch 87/100
# 8/8 [==============================] - 0s 17ms/step - loss: 17.3670 - accuracy: 0.8600 - val_loss: 67.8426 - val_accuracy: 0.6150
# Epoch 88/100
# 8/8 [==============================] - 0s 18ms/step - loss: 6.4918 - accuracy: 0.9150 - val_loss: 60.3756 - val_accuracy: 0.5850
# Epoch 89/100
# 8/8 [==============================] - 0s 18ms/step - loss: 0.4291 - accuracy: 0.9850 - val_loss: 59.2729 - val_accuracy: 0.5800
# Epoch 90/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.5951 - accuracy: 0.9800 - val_loss: 81.0966 - val_accuracy: 0.5850
# Epoch 91/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.5657 - accuracy: 0.9400 - val_loss: 58.0301 - val_accuracy: 0.5650
# Epoch 92/100
# 8/8 [==============================] - 0s 17ms/step - loss: 2.1764 - accuracy: 0.9450 - val_loss: 79.4973 - val_accuracy: 0.5650
# Epoch 93/100
# 8/8 [==============================] - 0s 17ms/step - loss: 3.6429 - accuracy: 0.9275 - val_loss: 58.4516 - val_accuracy: 0.5900
# Epoch 94/100
# 8/8 [==============================] - 0s 24ms/step - loss: 0.5503 - accuracy: 0.9825 - val_loss: 69.8987 - val_accuracy: 0.6100
# Epoch 95/100
# 8/8 [==============================] - 0s 17ms/step - loss: 8.3962 - accuracy: 0.8975 - val_loss: 115.2921 - val_accuracy: 0.5850
# Epoch 96/100
# 8/8 [==============================] - 0s 19ms/step - loss: 21.0021 - accuracy: 0.8175 - val_loss: 63.7995 - val_accuracy: 0.5900
# Epoch 97/100
# 8/8 [==============================] - 0s 16ms/step - loss: 2.1904 - accuracy: 0.9600 - val_loss: 63.8232 - val_accuracy: 0.5600
# Epoch 98/100
# 8/8 [==============================] - 0s 23ms/step - loss: 0.7429 - accuracy: 0.9750 - val_loss: 59.7408 - val_accuracy: 0.5900
# Epoch 99/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.2564 - accuracy: 0.9850 - val_loss: 61.8040 - val_accuracy: 0.5750
# Epoch 100/100
# 8/8 [==============================] - 0s 17ms/step - loss: 0.4301 - accuracy: 0.9800 - val_loss: 58.2457 - val_accuracy: 0.6100
# time to load data 0:05:26.198015

# %%
model_nn.save(PROJECT_PATH+"model_nn.h5")

# %%
history_nn.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plot_history(history_nn)
